# %%
from pvrecorder import PvRecorder
import wave,struct

# %%
for index, device in enumerate(PvRecorder.get_available_devices()):
    print(f"""[{index}]  {device}""")
# Out:
# [0]  Stereo Mix (2- Realtek(R) Audio)
# [1]  Microphone (2- Realtek(R) Audio)

# %%
# Out:
# Recording both Mic and Speakers... Press Ctrl+C to stop.
#
# Processing audio... please wait.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 42
#      41 try:
# ---> 42     while True:
#      43         pass # Keep the main thread alive
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 52
#      47 t1.join()
#      48 # t2.join()
#      49
#      50 # --- MIXING LOGIC ---
#      51 # We find the shortest list to avoid errors, then average the samples
# ---> 52 min_length = min(len(mic_audio))
#      53 mixed_audio = []
#      55 for i in range(min_length):
#      56     # Mix by adding samples and dividing by 2 (averaging)
#      57     # to prevent "clipping" (distortion)
#
# TypeError: 'int' object is not iterable
